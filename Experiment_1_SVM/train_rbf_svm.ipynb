# %% [markdown]
# # RBF SVM Classifier for Founder Retention Prediction
#
# This notebook trains a non-linear Support Vector Machine (SVM) classifier with RBF (Radial Basis Function) kernel to predict whether a founder will stay with or leave their startup.
#
# **Experiment**: RBF SVM (Non-Linear)
# **Kernel**: RBF (Radial Basis Function)
# **Task**: Binary Classification (Stayed vs Left)

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import time
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
print(f"Experiment: RBF SVM (Non-Linear)")
# Out:
# Libraries imported successfully!
# Experiment: RBF SVM (Non-Linear)

# %%
# Load preprocessed data
X_train_split = pd.read_csv('dataset/X_train_split.csv')
X_val_split = pd.read_csv('dataset/X_val_split.csv')
y_train_split = pd.read_csv('dataset/y_train_split.csv').values.ravel()
y_val_split = pd.read_csv('dataset/y_val_split.csv').values.ravel()

# Load full training data for final model
X_train_full = pd.read_csv('dataset/X_train_preprocessed.csv')
y_train_full = pd.read_csv('dataset/y_train.csv').values.ravel()

# Load test data
X_test = pd.read_csv('dataset/X_test_preprocessed.csv')

# Load test IDs
test_ids = pd.read_csv('dataset/test.csv')['founder_id']

# Load label encoder
with open('dataset/label_encoder.pkl', 'rb') as f:
    label_encoder = pickle.load(f)

print("Data loaded successfully!")
print(f"Training set: {X_train_split.shape}")
print(f"Validation set: {X_val_split.shape}")
print(f"Full training set: {X_train_full.shape}")
print(f"Test set: {X_test.shape}")
print(f"Test IDs: {len(test_ids)}")
# Out:
# Data loaded successfully!
# Training set: (47688, 26)
# Validation set: (11923, 26)
# Full training set: (59611, 26)
# Test set: (14900, 26)
# Test IDs: 14900

# %% [markdown]
# ## 2. Train RBF SVM Model

# %%
# Initialize RBF SVM with default parameters
print("Training RBF SVM (kernel='rbf')...")
print("RBF kernel can capture non-linear relationships in the data")
print("This may take several minutes...\n")

start_time = time.time()

# Create RBF SVM classifier
# gamma='scale' uses 1 / (n_features * X.var()) as value of gamma
rbf_svm = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    random_state=42,
    verbose=1
)

# Train the model
rbf_svm.fit(X_train_split, y_train_split)

training_time = time.time() - start_time

print(f"\n✓ Training completed in {training_time:.2f} seconds")
print(f"Number of support vectors: {len(rbf_svm.support_vectors_)}")
# Out:
# Training RBF SVM (kernel='rbf')...
# RBF kernel can capture non-linear relationships in the data
# This may take several minutes...
#
# [LibSVM]......................................................................*..*......................*..*..*
# optimization finished, #iter = 48734
# obj = -28767.627281, rho = 0.148481
# nSV = 32208, nBSV = 28750
# Total nSV = 32208
#
# ✓ Training completed in 91.42 seconds
# Number of support vectors: 32208
# *
# optimization finished, #iter = 48734
# obj = -28767.627281, rho = 0.148481
# nSV = 32208, nBSV = 28750
# Total nSV = 32208
#
# ✓ Training completed in 91.42 seconds
# Number of support vectors: 32208

# %% [markdown]
# ## 3. Evaluate Model on Validation Set

# %%
# Make predictions on validation set
y_val_pred = rbf_svm.predict(X_val_split)

# Calculate metrics
accuracy = accuracy_score(y_val_split, y_val_pred)
precision = precision_score(y_val_split, y_val_pred)
recall = recall_score(y_val_split, y_val_pred)
f1 = f1_score(y_val_split, y_val_pred)

print("="*60)
print("RBF SVM - VALIDATION SET PERFORMANCE")
print("="*60)
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
print("="*60)

# Detailed classification report
print("\nClassification Report:")
print(classification_report(y_val_split, y_val_pred, 
                          target_names=['Left', 'Stayed']))
# Out:
# ============================================================
# RBF SVM - VALIDATION SET PERFORMANCE
# ============================================================
# Accuracy:  0.6977
# Precision: 0.7010
# Recall:    0.7387
# F1-Score:  0.7194
# ============================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Left       0.69      0.65      0.67      5670
#       Stayed       0.70      0.74      0.72      6253
#
#     accuracy                           0.70     11923
#    macro avg       0.70      0.70      0.70     11923
# weighted avg       0.70      0.70      0.70     11923

# %%
# Confusion Matrix
cm = confusion_matrix(y_val_split, y_val_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', 
            xticklabels=['Left', 'Stayed'],
            yticklabels=['Left', 'Stayed'])
plt.title('Confusion Matrix - RBF SVM', fontsize=14, fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

print(f"\nTrue Negatives:  {cm[0, 0]}")
print(f"False Positives: {cm[0, 1]}")
print(f"False Negatives: {cm[1, 0]}")
print(f"True Positives:  {cm[1, 1]}")
# Out:
# True Negatives:  3700
# False Positives: 1970
# False Negatives: 1634
# True Positives:  4619

# %% [markdown]
# ## 4. Train Final Model on Full Training Data

# %%
# Train final model on all training data
print("Training final RBF SVM model on full training data...")
print("This may take several minutes...\n")

start_time = time.time()

final_rbf_svm = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    random_state=42,
    verbose=1
)

final_rbf_svm.fit(X_train_full, y_train_full)

final_training_time = time.time() - start_time

print(f"\n✓ Final model training completed in {final_training_time:.2f} seconds")
print(f"Number of support vectors: {len(final_rbf_svm.support_vectors_)}")
print(f"Training samples used: {X_train_full.shape[0]}")
# Out:
# Training final RBF SVM model on full training data...
# This may take several minutes...
#
# [LibSVM]............................................................................................*.*...............................*.*.....*
# optimization finished, #iter = 64173
# obj = -36099.054554, rho = 0.138937
# nSV = 40061, nBSV = 35930
# Total nSV = 40061
#
# ✓ Final model training completed in 180.45 seconds
# Number of support vectors: 40061
# Training samples used: 59611
# *
# optimization finished, #iter = 64173
# obj = -36099.054554, rho = 0.138937
# nSV = 40061, nBSV = 35930
# Total nSV = 40061
#
# ✓ Final model training completed in 180.45 seconds
# Number of support vectors: 40061
# Training samples used: 59611

# %% [markdown]
# ## 5. Generate Predictions on Test Set

# %%
# Make predictions on test set
print("Generating predictions on test set...")
y_test_pred_encoded = final_rbf_svm.predict(X_test)

# Convert predictions back to original labels
y_test_pred_labels = label_encoder.inverse_transform(y_test_pred_encoded)

print(f"✓ Predictions generated for {len(y_test_pred_labels)} test samples")
print(f"\nPrediction distribution:")
unique, counts = np.unique(y_test_pred_labels, return_counts=True)
for label, count in zip(unique, counts):
    print(f"  {label}: {count} ({count/len(y_test_pred_labels)*100:.2f}%)")
# Out:
# Generating predictions on test set...
# ✓ Predictions generated for 14900 test samples
#
# Prediction distribution:
#   Left: 6631 (44.50%)
#   Stayed: 8269 (55.50%)
# ✓ Predictions generated for 14900 test samples
#
# Prediction distribution:
#   Left: 6631 (44.50%)
#   Stayed: 8269 (55.50%)

# %% [markdown]
# ## 6. Save Results to CSV

# %%
# Create submission dataframe
submission_df = pd.DataFrame({
    'founder_id': test_ids,
    'retention_status': y_test_pred_labels
})

# Save to CSV
output_filename = 'test_result_rbf_svm.csv'
submission_df.to_csv(output_filename, index=False)

print(f"✓ Results saved to '{output_filename}'")
print(f"\nSubmission file preview:")
display(submission_df.head(10))
print(f"\nTotal predictions: {len(submission_df)}")
print(f"File size: {submission_df.memory_usage(deep=True).sum() / 1024:.2f} KB")
# Out:
# ✓ Results saved to 'test_result_rbf_svm.csv'
#
# Submission file preview:
#    founder_id retention_status
# 0       52685           Stayed
# 1       30585             Left
# 2       54656           Stayed
# 3       33442             Left
# 4       15667           Stayed
# 5        3496             Left
# 6       46775           Stayed
# 7       72645             Left
# 8        4941           Stayed
# 9       65181             Left
# Total predictions: 14900
# File size: 1020.28 KB

# %% [markdown]
# ## 7. Summary

# %%
print("="*70)
print("RBF SVM TRAINING SUMMARY")
print("="*70)
print(f"\n📊 Model Configuration:")
print(f"   - Kernel: RBF (Radial Basis Function)")
print(f"   - Regularization (C): 1.0")
print(f"   - Gamma: scale (auto)")
print(f"   - Features: {X_train_full.shape[1]}")
print(f"   - Training samples: {X_train_full.shape[0]}")

print(f"\n⏱️  Training Time:")
print(f"   - Validation model: {training_time:.2f} seconds")
print(f"   - Final model: {final_training_time:.2f} seconds")

print(f"\n📈 Validation Performance:")
print(f"   - Accuracy:  {accuracy:.4f}")
print(f"   - Precision: {precision:.4f}")
print(f"   - Recall:    {recall:.4f}")
print(f"   - F1-Score:  {f1:.4f}")

print(f"\n💾 Output:")
print(f"   - File: {output_filename}")
print(f"   - Test predictions: {len(submission_df)}")

print(f"\n🎯 RBF Kernel Advantage:")
print(f"   - Captures non-linear relationships")
print(f"   - Can model complex decision boundaries")
print(f"   - Often performs better than linear kernel")

print("\n" + "="*70)
print("✓ RBF SVM training completed successfully!")
print("="*70)
# Out:
# ======================================================================
# RBF SVM TRAINING SUMMARY
# ======================================================================
#
# 📊 Model Configuration:
#    - Kernel: RBF (Radial Basis Function)
#    - Regularization (C): 1.0
#    - Gamma: scale (auto)
#    - Features: 26
#    - Training samples: 59611
#
# ⏱️  Training Time:
#    - Validation model: 91.42 seconds
#    - Final model: 180.45 seconds
#
# 📈 Validation Performance:
#    - Accuracy:  0.6977
#    - Precision: 0.7010
#    - Recall:    0.7387
#    - F1-Score:  0.7194
#
# 💾 Output:
#    - File: test_result_rbf_svm.csv
#    - Test predictions: 14900
#
# 🎯 RBF Kernel Advantage:
#    - Captures non-linear relationships
#    - Can model complex decision boundaries
#    - Often performs better than linear kernel
#
# ======================================================================
# ✓ RBF SVM training completed successfully!
# ======================================================================
